# %%
import pandas as pd
import numpy as np
import torch
import random
import matplotlib.pyplot as plt

import dataprovider_pypots as dp
import process_edited as pce
import VAE as vae
import DIFF as diff_mod   # DIFF 모듈
import Evaluation.Metrics as mt
import Evaluation.predictive_metrics as pdm

from dataprovider_pypots import (
    add_continuous_metadata_noise_subset,
    flip_categorical_metadata_subset,
)

device = 'cuda'

# ------------------------
# 1. 데이터셋 설정
# ------------------------
# time_col은 실제 데이터셋 column 이름에 맞게 확인해서 수정해줘야 함!
dataset_configs = {
    #"Metro_Traffic": {
    #    "path": "dataset/Metro_Traffic.csv",
    #    "reader": pd.read_csv,
    #    "target_columns": ["weather_main", "temp"],
    #    "time_col": "date",       # 실제 time 컬럼명 확인 필요
    #},
    #"Pollution Data": {
    #    "path": "dataset/Pollution Data.csv",
    #    "reader": pd.read_csv,
    #    "target_columns": ["cbwd", "Iws"],
    #    "time_col": "date",
    #},
    "Hurricane": {
        "path": "dataset/Hurricane.csv",
        "reader": pd.read_csv,
        "target_columns": ["year", "trend"],
        "time_col": "date",       # 실제 time 컬럼명에 맞게 수정
    },
    #"AirQuality": {
    #    "path": "dataset/AirQuality.csv",
    #    "reader": pd.read_csv,
    #    "target_columns": ["NOx(GT)", "NO2(GT)"],
    #    "time_col": "date",       # 예시: 실제 컬럼명 확인 필요
    #},
    #"ETTh1": {
    #    "path": "dataset/ETTh1.csv",
    #    "reader": pd.read_csv,
    #    "target_columns": ["LULL", "OT"],
    #    "time_col": "date",       # 실제 컬럼명에 맞게 수정
    #},
    #"Energy": {
    #    "path": "dataset/energy_data.csv",
    #    "reader": pd.read_csv,
    #    "target_columns": ["lights", "rv1"],
    #    "time_col": "date",       # 실제 컬럼명에 맞게 수정
    #},
}

# ------------------------
# 2. 공통 하이퍼파라미터
# ------------------------
VAE_training = 2
diff_training = 3
lat_dim = 6

vae_n_epochs = VAE_training
eps = 1e-5
weight_decay = 1e-6
lr = 2e-4
hidden_size = 512
num_layers_vae = 2
batch_size = 100
channels = 64
min_beta = 1e-5
max_beta = 0.1
emb_dim = 128
time_dim = 8
threshold = 1

diff_n_epochs = diff_training
hidden_dim = 200
num_layers_diff = 2
diffusion_steps = 100

# robustness 실험 설정
levels = [0.0, 0.1, 0.2, 0.4, 0.6]
iterations = 1000
num_runs = 5

seq_len = 24
stride = 1
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

# ------------------------
# 3. 결과 저장용 딕셔너리
# ------------------------
disc_results = {}  # {dataset_name: {"mean": [...], "std": [...]} }
temp_results = {}

# ------------------------
# 4. 데이터셋 루프
# ------------------------
for ds_name, cfg in dataset_configs.items():
    print(f"\n\n==============================")
    print(f"=== Dataset: {ds_name} ===")
    print(f"==============================")

    # 4-1) 데이터 로딩
    reader = cfg["reader"]
    path = cfg["path"]
    target_columns = cfg["target_columns"]
    time_col = cfg["time_col"]

    real_df = reader(path)

    # --- 데이터셋별 간단 전처리 (필요시 조건문 추가) ---
    if ds_name == "bike_sharing":
        cols = real_df.columns.to_list()
        cols[1] = "date"
        real_df.columns = cols
        real_df = real_df.drop(columns=["instant", "yr", "mnth"])
    if ds_name == "Metro_Traffic":
        if "holiday" in real_df.columns:
            real_df["holiday"] = real_df["holiday"].fillna(0)
    if ds_name == "Pollution Data":
        if "pm2.5" in real_df.columns:
            real_df["pm2.5"] = real_df["pm2.5"].fillna(0)

    # time_col이 실제로 존재하는지 체크 (없으면 에러)
    assert time_col in real_df.columns, f"{ds_name}: time_col '{time_col}' not found in columns!"

    # 4-2) TVMCG용 데이터 준비
    real_df1 = real_df.drop([time_col], axis=1)
    parser = pce.DataFrameParser().fit(real_df1, 1)
    column_name = parser.column_name()

    pdset = dp.TVMCG(
        real_df.iloc[0:2000, :],  # 필요시 길이 조정
        train_ratio=train_ratio,
        val_ratio=val_ratio,
        test_ratio=test_ratio,
        seq_len=seq_len,
        stride=stride,
        column_list=column_name,
        target_column=target_columns,
    )

    # 4-3) VAE 학습
    ds = vae.train_autoencoder(
        None,
        channels,
        hidden_size,
        num_layers_vae,
        lr,
        weight_decay,
        vae_n_epochs,
        batch_size,
        threshold,
        min_beta,
        max_beta,
        emb_dim,
        time_dim,
        lat_dim,
        device,
        pdset,
    )
    latent_features = ds[1]

    # 4-4) Diffusion 학습
    num_classes = len(latent_features)
    diff_model = diff_mod.train_diffusion(
        latent_features,
        None,
        pdset,
        hidden_dim,
        num_layers_diff,
        diffusion_steps,
        diff_n_epochs,
        num_classes,
    )

    # 4-5) Robustness 실험 준비
    Batch_size, Seq_len, _ = pdset["response_train"].shape
    Lat_dim = lat_dim

    base_target_mask = pdset["target_mask_train"]
    base_target = pdset["response_train"]
    base_cond = pdset["cond_train"]
    base_time_info = pdset["time_info_train"]

    target_idx = pdset["target_idx"]
    cont_meta_idx = pdset["cond_cont_idx"]
    cat_meta_idx = pdset["cond_cat_idx"]
    cat_num_classes = pdset["cat_num_classes_idx"]

    disc_mean = []
    disc_std = []
    tmp_mean = []
    tmp_std = []

    # 4-6) level 루프
    for level in levels:
        print(f"\n=== {ds_name} | Level {level} ===")
        disc_scores = []
        tmp_scores = []

        for run in range(num_runs):
            print(f"  Run {run+1}/{num_runs}...")

            # (1) metadata corruption
            cond_clean = base_cond.clone()
            cond_test_noisy = add_continuous_metadata_noise_subset(
                cond=cond_clean,
                cont_idx=cont_meta_idx,
                level=level,
            )
            cond_test_flipped = flip_categorical_metadata_subset(
                cond=cond_test_noisy,
                cat_idx=cat_meta_idx,
                p=level,
                num_classes_dict=cat_num_classes,
            )

            # (2) 준비
            target_mask_test = base_target_mask.to(device).float()
            target_test = base_target.to(device)
            cond_test = cond_test_flipped.to(device)
            time_info_test = base_time_info.to(device)

            # (3) Sampling
            t_grid = torch.linspace(0, 1, Seq_len).view(1, -1, 1).to(device)
            samples = diff_mod.sample(
                t_grid.repeat(Batch_size, 1, 1),
                Batch_size,
                Seq_len,
                Lat_dim,
                diffusion_steps,
                diff_model,
                time_info_test,
                cond_test,
                target_mask_test,
            )

            # (4) Decode
            parser = pdset["parser"]  # TVMCG에서 저장한 parser
            gen_output = ds[0].decoder(samples.to(device), target_mask_test, cond_test)
            _synth_data = pce.convert_to_tensor(parser, gen_output, 1, Batch_size, Seq_len)
            
            # (5) target feature만 사용
            target_test1 = target_test[:, :, target_idx].detach().cpu()
            _synth_data1 = _synth_data[:, :, target_idx].detach().cpu()

            # (6) Metrics
            disc_score = mt.discriminative_score_metrics(
                target_test1, _synth_data1, iterations
            )
            tmp_score = mt.temp_disc_score(
                target_test1, _synth_data1, iterations
            )

            if torch.is_tensor(disc_score):
                disc_score = float(disc_score)
            if torch.is_tensor(tmp_score):
                tmp_score = float(tmp_score)

            disc_scores.append(disc_score)
            tmp_scores.append(tmp_score)

        # level별 평균 / 표준편차
        disc_mean.append(np.mean(disc_scores))
        disc_std.append(np.std(disc_scores))
        tmp_mean.append(np.mean(tmp_scores))
        tmp_std.append(np.std(tmp_scores))

        print(f"→ {ds_name} | Disc mean ± std: {disc_mean[-1]:.4f} ± {disc_std[-1]:.4f}")
        print(f"→ {ds_name} | Temp mean ± std: {tmp_mean[-1]:.4f} ± {tmp_std[-1]:.4f}")

    # 데이터셋별 결과 저장
    disc_results[ds_name] = {"mean": disc_mean, "std": disc_std}
    temp_results[ds_name] = {"mean": tmp_mean, "std": tmp_std}

# ------------------------
# 5. 최종 플롯 (데이터셋별 곡선 같이 보기)
# ------------------------

# Plot A: Discriminative Score
plt.figure(figsize=(7, 5))
for ds_name in dataset_configs.keys():
    dm = disc_results[ds_name]["mean"]
    ds = disc_results[ds_name]["std"]
    plt.errorbar(
        levels,
        dm,
        yerr=ds,
        marker="o",
        capsize=3,
        label=ds_name,
    )

plt.xlabel("Metadata corruption level (p)")
plt.ylabel("Discriminative Score")
plt.title(f"Discriminative Score vs Metadata Corruption\n(mean of {num_runs} runs)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# Plot B: Temporal Score
plt.figure(figsize=(7, 5))
for ds_name in dataset_configs.keys():
    tm = temp_results[ds_name]["mean"]
    ts = temp_results[ds_name]["std"]
    plt.errorbar(
        levels,
        tm,
        yerr=ts,
        marker="s",
        capsize=3,
        label=ds_name,
    )

plt.xlabel("Metadata corruption level (p)")
plt.ylabel("Temporal Score")
plt.title(f"Temporal Score vs Metadata Corruption\n(mean of {num_runs} runs)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# (선택) 숫자 테이블 출력
print("\n=== Summary (Discriminative) ===")
print("Dataset | Level | Mean | Std")
for ds_name in dataset_configs.keys():
    for l, m, s in zip(levels, disc_results[ds_name]["mean"], disc_results[ds_name]["std"]):
        print(f"{ds_name} | {l:.2f} | {m:.4f} | {s:.4f}")

print("\n=== Summary (Temporal) ===")
print("Dataset | Level | Mean | Std")
for ds_name in dataset_configs.keys():
    for l, m, s in zip(levels, temp_results[ds_name]["mean"], temp_results[ds_name]["std"]):
        print(f"{ds_name} | {l:.2f} | {m:.4f} | {s:.4f}")
# Out:
# ==============================
# === Dataset: Hurricane ===
# ==============================
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# === Hurricane | Level 0.0 ===
#   Run 1/5...
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [65,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [67,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [69,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [71,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [73,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [75,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [77,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [79,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [81,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [83,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [85,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [87,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [89,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [91,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [93,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [43,0,0], thread: [95,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [97,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [99,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [101,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [103,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [105,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [107,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [109,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [111,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [113,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [115,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [117,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [119,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [121,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [123,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [125,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [39,0,0], thread: [127,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [97,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [99,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [101,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [103,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [105,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [107,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [109,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [111,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [113,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [115,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [117,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [119,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [121,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [123,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [125,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [95,0,0], thread: [127,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [65,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [67,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [69,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [71,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [73,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [75,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [77,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [79,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [81,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [83,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [85,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [87,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [89,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [91,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [93,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [82,0,0], thread: [95,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [1,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [3,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [5,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [7,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [9,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [11,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [13,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [15,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [17,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [19,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [21,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [23,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [25,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [27,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [29,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [33,0,0], thread: [31,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [1,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [3,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [5,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [7,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [9,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [11,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [13,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [15,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [17,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [19,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [21,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [23,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [25,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [27,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [29,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [87,0,0], thread: [31,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [97,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [99,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [101,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [103,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [105,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [107,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [109,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [111,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [113,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [115,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [117,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [119,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [121,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [123,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [125,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [76,0,0], thread: [127,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [1,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [3,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [5,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [7,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [9,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [11,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [13,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [15,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [17,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [19,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [21,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [23,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [25,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [27,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [29,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [31,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [97,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [99,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [101,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [103,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [105,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [107,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [109,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [111,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [113,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [115,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [117,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [119,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [121,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [123,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [125,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [72,0,0], thread: [127,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [97,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [99,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [101,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [103,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [105,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [107,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [109,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [111,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [113,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [115,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [117,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [119,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [121,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [123,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [125,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [127,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [33,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [35,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [37,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [39,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [41,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [43,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [45,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [47,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [49,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [51,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [53,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [55,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [57,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [59,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [61,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [74,0,0], thread: [63,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [65,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [67,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [69,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [71,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [73,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [75,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [77,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [79,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [81,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [83,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [85,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [87,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [89,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [91,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [93,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [75,0,0], thread: [95,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [65,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [67,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [69,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [71,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [73,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [75,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [77,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [79,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [81,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [83,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [85,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [87,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [89,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [91,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [93,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [95,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [1,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [3,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [5,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [7,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [9,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [11,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [13,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [15,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [17,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [19,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [21,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [23,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [25,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [27,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [29,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [68,0,0], thread: [31,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [33,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [35,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [37,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [39,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [41,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [43,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [45,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [47,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [49,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [51,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [53,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [55,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [57,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [59,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [61,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [10,0,0], thread: [63,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [14,0,0], thread: [97,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [14,0,0], thread: [99,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ...
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [103,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [105,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [107,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [109,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [111,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [113,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [115,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [117,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [119,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [121,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [123,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [125,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [15,0,0], thread: [127,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [1,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [3,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [5,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [7,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [9,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [11,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [13,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [15,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [17,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [19,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [21,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [23,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [25,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [27,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [29,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [11,0,0], thread: [31,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [65,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [67,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [69,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [71,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [73,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [75,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [77,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [79,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [81,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [83,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [85,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [87,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [89,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [91,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [93,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [6,0,0], thread: [95,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [65,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [67,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [69,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [71,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [73,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [75,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [77,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [79,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [81,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [83,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [85,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [87,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [89,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [91,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [93,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [7,0,0], thread: [95,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [1,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [3,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [5,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [7,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [9,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [11,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [13,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [15,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [17,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [19,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [21,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [23,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [25,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [27,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [29,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# /opt/pytorch/pytorch/aten/src/ATen/native/cuda/IndexKernel.cu:94: operator(): block: [2,0,0], thread: [31,0,0] Assertion `-sizes[i] <= index && index < sizes[i] && "index out of bounds"` failed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 257
#     255 # (5) target feature만 사용
#     256 target_test1 = target_test[:, :, target_idx].detach().cpu()
# --> 257 _synth_data1 = _synth_data[:, :, target_idx].detach().cpu()
#     259 # (6) Metrics
#     260 disc_score = mt.discriminative_score_metrics(
#     261     target_test1, _synth_data1, iterations
#     262 )
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 4)) 
label = 19
# Plot histogram for the specified column
for i in range(0,2):
    axes[i].plot(target_test1[label,:,i],  marker='o', linestyle='-', color='b')
    axes[i].plot(_synth_data1[label,:,i].cpu(),  marker='o', linestyle='-', color='r')
    axes[i].set_xlabel('Time')
    axes[i].set_ylabel(f'{column_name[i]}')
    axes[i].grid(True)
    axes[i].legend(loc='upper left')

plt.show()

# %%
_synth_data
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py:770, in PlainTextFormatter.__call__(self, obj)
#     763 stream = StringIO()
#     764 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     765     self.max_width, self.newline,
#     766     max_seq_length=self.max_seq_length,
#     767     singleton_pprinters=self.singleton_printers,
#     768     type_pprinters=self.type_printers,
#     769     deferred_pprinters=self.deferred_printers)
# --> 770 printer.pretty(obj)
#     771 printer.flush()
#     772 return stream.getvalue()
#
# File /usr/local/lib/python3.12/dist-packages/IPython/lib/pretty.py:419, in RepresentationPrinter.pretty(self, obj)
#     408                         return meth(obj, self, cycle)
#     409                 if (
#     410                     cls is not object
#     411                     # check if cls defines __repr__
#    (...)
#     417                     and callable(_safe_getattr(cls, "__repr__", None))
#     418                 ):
# --> 419                     return _repr_pprint(obj, self, cycle)
#     421     return _default_pprint(obj, self, cycle)
#     422 finally:
#
# File /usr/local/lib/python3.12/dist-packages/IPython/lib/pretty.py:794, in _repr_pprint(obj, p, cycle)
#     792 """A pprint that just redirects to the normal repr function."""
#     793 # Find newlines and replace them with p.break_()
# --> 794 output = repr(obj)
#     795 lines = output.splitlines()
#     796 with p.group():
#
# File /usr/local/lib/python3.12/dist-packages/torch/_tensor.py:568, in Tensor.__repr__(self, tensor_contents)
#     564     return handle_torch_function(
#     565         Tensor.__repr__, (self,), self, tensor_contents=tensor_contents
#     566     )
#     567 # All strings are unicode in Python 3.
# --> 568 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File /usr/local/lib/python3.12/dist-packages/torch/_tensor_str.py:708, in _str(self, tensor_contents)
#     706 with torch.no_grad(), torch.utils._python_dispatch._disable_current_modes():
#     707     guard = torch._C._DisableFuncTorch()
# --> 708     return _str_intern(self, tensor_contents=tensor_contents)
#
# File /usr/local/lib/python3.12/dist-packages/torch/_tensor_str.py:625, in _str_intern(inp, tensor_contents)
#     623                     tensor_str = _tensor_str(self.to_dense(), indent)
#     624                 else:
# --> 625                     tensor_str = _tensor_str(self, indent)
#     627 if self.layout != torch.strided:
#     628     suffixes.append("layout=" + str(self.layout))
#
# File /usr/local/lib/python3.12/dist-packages/torch/_tensor_str.py:357, in _tensor_str(self, indent)
#     353     return _tensor_str_with_formatter(
#     354         self, indent, summarize, real_formatter, imag_formatter
#     355     )
#     356 else:
# --> 357     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     358     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File /usr/local/lib/python3.12/dist-packages/torch/_tensor_str.py:393, in get_summarized_data(self)
#     391     start = [self[i] for i in range(0, PRINT_OPTS.edgeitems)]
#     392     end = [self[i] for i in range(len(self) - PRINT_OPTS.edgeitems, len(self))]
# --> 393     return torch.stack([get_summarized_data(x) for x in (start + end)])
#     394 else:
#     395     return torch.stack([get_summarized_data(x) for x in self])
#
# File /usr/local/lib/python3.12/dist-packages/torch/_tensor_str.py:393, in get_summarized_data(self)
#     391     start = [self[i] for i in range(0, PRINT_OPTS.edgeitems)]
#     392     end = [self[i] for i in range(len(self) - PRINT_OPTS.edgeitems, len(self))]
# --> 393     return torch.stack([get_summarized_data(x) for x in (start + end)])
#     394 else:
#     395     return torch.stack([get_summarized_data(x) for x in self])
#
# File /usr/local/lib/python3.12/dist-packages/torch/_tensor_str.py:383, in get_summarized_data(self)
#     381 if dim == 1:
#     382     if self.size(0) > 2 * PRINT_OPTS.edgeitems:
# --> 383         return torch.cat(
#     384             (self[: PRINT_OPTS.edgeitems], self[-PRINT_OPTS.edgeitems :])
#     385         )
#     386     else:
#     387         return self
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
